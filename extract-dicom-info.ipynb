# %%
# !pip install pydicom
import os
import pydicom
def Extract_Dicom_info(file_path):
    try:
        # Read the DICOM file
        dicom_file = pydicom.dcmread(file_path)
        
        # Extract patient-specific information if it is not anonymized
        print("*** Patient Information ***")
        print("")
        if 'PatientName' in dicom_file:
            print(f"Patient Name is: {dicom_file.PatientName}")
        if 'PatientID' in dicom_file:
            print(f"Patient ID is: {dicom_file.PatientID}")
        if 'PatientAge' in dicom_file:
            print(f"Patient Age is: {dicom_file.PatientAge}")
        if 'PatientSex' in dicom_file:
            print(f"Patient Sex is: {dicom_file.PatientSex}")
        
        print("")
        
        # Extract image-specific information
        print("***  Image Information  ***")
        print("")
        if 'SliceThickness' in dicom_file:
            print(f"Slice Thickness: {dicom_file.SliceThickness} mm")
        if 'Rows' in dicom_file:
            print(f"Rows: {dicom_file.Rows}")
        if 'Columns' in dicom_file:
            print(f"Columns: {dicom_file.Columns}")
        if 'PixelSpacing' in dicom_file:
            print(f"Pixel Spacing: {dicom_file.PixelSpacing} mm")
        
        # Extract the number of slices in each CT scan series 
        dicom_dir = os.path.dirname(file_path)
        dicom_files = [f for f in os.listdir(dicom_dir) if f.endswith('.dcm')]
        print(f"Number of 2D slices in CT series is: {len(dicom_files)} slices")
        
    except Exception as e:
        print(f"Failed to read DICOM file: {e}")

# Replace with the directory path of your DICOM file
dicom_file_path = "C:/Users/user/Desktop/CT-Volume/IMG-0001-00001.dcm"
Extract_Dicom_info(dicom_file_path)
# Out:
# Requirement already satisfied: pydicom in /usr/local/lib/python3.10/dist-packages (3.0.1)
# *** Patient Information ***
#
# Patient Name is:
# Patient ID is:
# Patient Age is:
# Patient Sex is:
#
# ***  Image Information  ***
#
# Slice Thickness: 3 mm
# Rows: 512
# Columns: 512
# Pixel Spacing: [0.943359375, 0.943359375] mm
# Number of 2D slices in CT series is: 40 slices

# %%
# Extract general information
dcm_img = pydicom.dcmread('C:/Users/user/Desktop/CT-Volume/IMG-0001-00001.dcm', force=True)
dcm_img
# Out:
# Dataset.file_meta -------------------------------
# (0002,0000) File Meta Information Group Length  UL: 206
# (0002,0001) File Meta Information Version       OB: b'\x00\x01'
# (0002,0002) Media Storage SOP Class UID         UI: CT Image Storage
# (0002,0003) Media Storage SOP Instance UID      UI: 1.3.46.670589.33.1.63827619491697766800001.5739217690858067119
# (0002,0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
# (0002,0012) Implementation Class UID            UI: 1.2.276.0.7230010.3.0.3.6.7
# (0002,0013) Implementation Version Name         SH: 'OFFIS_DCMTK_367'
# -------------------------------------------------
# (0008,0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008,0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'AXIAL']
# (0008,0012) Instance Creation Date              DA: '20230814'
# (0008,0013) Instance Creation Time              TM: '141811.714'
# (0008,0016) SOP Class UID                       UI: CT Image Storage
# (0008,0018) SOP Instance UID                    UI: 1.3.46.670589.33.1.63827619491697766800001.5739217690858067119
# (0008,0020) Study Date                          DA: ''
# (0008,0021) Series Date                         DA: ''
# (0008,0022) Acquisition Date                    DA: ''
# (0008,0023) Content Date                        DA: ''
# (0008,002A) Acquisition DateTime                DT: ''
# (0008,0030) Study Time                          TM: ''
# (0008,0031) Series Time                         TM: ''
# (0008,0032) Acquisition Time                    TM: ''
# (0008,0033) Content Time                        TM: ''
# (0008,0050) Accession Number                    SH: ''
# (0008,0060) Modality                            CS: 'CT'
# (0008,0070) Manufacturer                        LO: 'Philips'
# (0008,0080) Institution Name                    LO: ''
# (0008,0081) Institution Address                 ST: ''
# (0008,0090) Referring Physician's Name          PN: ''
# (0008,1010) Station Name                        SH: ''
# (0008,1030) Study Description                   LO: ''
# (0008,103E) Series Description                  LO: ''
# (0008,1040) Institutional Department Name       LO: ''
# (0008,1090) Manufacturer's Model Name           LO: 'Ingenuity CT'
# (0008,1111)  Referenced Performed Procedure Step Sequence  1 item(s) ----
#    (0008,1150) Referenced SOP Class UID            UI: Modality Performed Procedure Step SOP Class
#    (0008,1155) Referenced SOP Instance UID         UI: 1.3.46.670589.33.1.63827619155232522100001.5090182960614283116
#    ---------
# (0008,1140)  Referenced Image Sequence  1 item(s) ----
#    (0008,1150) Referenced SOP Class UID            UI: CT Image Storage
#    (0008,1155) Referenced SOP Instance UID         UI: 1.3.46.670589.33.1.63827619248669866400001.5353639418615664371
#    ---------
# (0008,3010) Irradiation Event UID               UI: ''
# (0010,0010) Patient's Name                      PN: ''
# (0010,0020) Patient ID                          LO: ''
# (0010,0030) Patient's Birth Date                DA: ''
# (0010,0040) Patient's Sex                       CS: ''
# (0010,1010) Patient's Age                       AS: ''
# (0018,0015) Body Part Examined                  CS: 'ABDOMEN'
# (0018,0022) Scan Options                        CS: 'HELIX'
# (0018,0050) Slice Thickness                     DS: '3'
# (0018,0060) KVP                                 DS: '120'
# (0018,0088) Spacing Between Slices              DS: '-1.5'
# (0018,0090) Data Collection Diameter            DS: '500'
# (0018,1000) Device Serial Number                LO: ''
# (0018,1020) Software Versions                   LO: '4.1'
# (0018,1030) Protocol Name                       LO: ''
# (0018,1100) Reconstruction Diameter             DS: '483'
# (0018,1110) Distance Source to Detector         DS: '1040'
# (0018,1111) Distance Source to Patient          DS: '570'
# (0018,1120) Gantry/Detector Tilt                DS: '0'
# (0018,1130) Table Height                        DS: '95.4'
# (0018,1150) Exposure Time                       IS: '640'
# (0018,1151) X-Ray Tube Current                  IS: '386'
# (0018,1152) Exposure                            IS: '247'
# (0018,1160) Filter Type                         SH: 'B'
# (0018,1210) Convolution Kernel                  SH: 'B'
# (0018,5100) Patient Position                    CS: 'HFS'
# (0018,9302) Acquisition Type                    CS: 'SPIRAL'
# (0018,9305) Revolution Time                     FD: 0.75
# (0018,9306) Single Collimation Width            FD: 0.625
# (0018,9307) Total Collimation Width             FD: 40.0
# (0018,9309) Table Speed                         FD: 62.5
# (0018,9310) Table Feed per Rotation             FD: 75.008
# (0018,9311) Spiral Pitch Factor                 FD: 1.172
# (0018,9323) Exposure Modulation Type            CS: '3D MODULATION'
# (0018,9324) Estimated Dose Saving               FD: -4.0
# (0018,9345) CTDIvol                             FD: 16.154008438818565
# (0020,000D) Study Instance UID                  UI: 1.3.46.670589.33.1.63827619155228521800001.5181452270009601956
# (0020,000E) Series Instance UID                 UI: 1.3.46.670589.33.1.63827619486242454800001.4784848181141126066
# (0020,0010) Study ID                            SH: ''
# (0020,0011) Series Number                       IS: '401'
# (0020,0012) Acquisition Number                  IS: '3'
# (0020,0013) Instance Number                     IS: '1'
# (0020,0032) Image Position (Patient)            DS: [-260.337, -127.785, -460.74]
# (0020,0037) Image Orientation (Patient)         DS: [1, 0, 0, 0, 1, 0]
# (0020,0052) Frame of Reference UID              UI: 1.3.46.670589.33.1.63782762271044535100002.4730373650421124647
# (0020,1040) Position Reference Indicator        LO: ''
# (0020,1041) Slice Location                      DS: '-460.74'
# (0020,4000) Image Comments                      LT: ''
# (0028,0002) Samples per Pixel                   US: 1
# (0028,0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028,0010) Rows                                US: 512
# (0028,0011) Columns                             US: 512
# (0028,0030) Pixel Spacing                       DS: [0.943359375, 0.943359375]
# (0028,0100) Bits Allocated                      US: 16
# (0028,0101) Bits Stored                         US: 12
# (0028,0102) High Bit                            US: 11
# (0028,0103) Pixel Representation                US: 0
# (0028,1050) Window Center                       DS: [60, 60]
# (0028,1051) Window Width                        DS: [350, 350]
# (0028,1052) Rescale Intercept                   DS: '-1024'
# (0028,1053) Rescale Slope                       DS: '1'
# (0032,1033) Requesting Service                  LO: ''
# (0040,1001) Requested Procedure ID              SH: ''
# (00E1,0010) Private Creator                     LO: 'ELSCINT1'
# (00E1,1002) Private tag data                    SH: 'Adult'
# (00E1,1036) Private tag data                    CS: 'YES'
# (00E1,1040) [Image Label]                       SH: 'VENOUS'
# (00E1,1046) Private tag data                    OB: Array of 512 elements
# (00E1,1050) [Acquisition Duration]              DS: '9.348'
# (00E1,1063) [Patient Language]                  SH: 'ARABIC'
# (00E1,10C4) [Abs Bed Pos]                       DS: '889.85595703125'
# (01F1,0010) Private Creator                     LO: 'ELSCINT1'
# (01F1,1001) [Acquisition Type]                  CS: 'SPIRAL'
# (01F1,1002) [Resolution]                        CS: 'STANDARD'
# (01F1,1004) [Angular Sampling]                  CS: 'NORMAL'
# (01F1,1008) [Scan Length]                       DS: '511.5'
# (01F1,100C) [Scanner Relative Center]           DS: [0.095, 0.039]
# (01F1,100E) [Recon Enhancement]                 FL: 0.0
# (01F1,100F) Private tag data                    CS: 'IN'
# (01F1,1026) [Pitch]                             DS: '1.172'
# (01F1,1027) [Rotation Time]                     DS: '0.75'
# (01F1,1032) [View Convention]                   CS: 'RIGHT_ON_LEFT'
# (01F1,1044) [Unknown]                           OW: Array of 644 elements
# (01F1,1046) [Unknown]                           FL: 0.625
# (01F1,1047) [Unknown]                           SH: '3D'
# (01F1,1049) [Planned mAs]                       DS: None
# (01F1,104A) [Unknown]                           SH: 'DOM'
# (01F1,104B) [Collimation]                       SH: '64x0.625'
# (01F1,104D) [Adaptive Filter]                   SH: 'YES'
# (01F1,104E) [Scan Type]                         SH: 'Abdomen/Pelvis'
# (01F1,1054) Private tag data                    IS: '17'
# (01F1,1056) Private tag data                    LO: '35.0198856813512'
# (01F7,0010) Private Creator                     LO: 'ELSCINT1'
# (01F7,1014) [Unknown]                           OW: Array of 108 elements
# (01F7,1019) [Unknown]                           OW: Array of 2160 elements
# (01F7,1022) [Unknown]                           UI: 1.3.46.670589.33.1.63827619437532668700002.4882624983413888482
# (01F7,1029) [Unknown]                           OW: Array of 440 elements
# (01F7,1031) [Unknown]                           OW: Array of 124 elements
# (01F7,1092) Private tag data                    OW: Array of 884 elements
# (01F7,1095) Private tag data                    OW: Array of 128 elements
# (01F7,1097) Private tag data                    OW: Array of 256 elements
# (01F7,1099) Private tag data                    OW: Array of 64 elements
# (01F7,109B) [iDose Level]                       IS: '4'
# (07A1,0010) Private Creator                     LO: 'ELSCINT1'
# (7FE0,0010) Pixel Data                          OW: Array of 524288 elements
